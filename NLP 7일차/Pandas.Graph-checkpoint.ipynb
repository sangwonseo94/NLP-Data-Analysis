# %%
import pandas as pd
import matplotlib.pyplot as plt
s1 = pd.Series([1,2,3,4,5,6,7])
s1.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f320b0b9281c> in <module>
#       3 s1 = pd.Series([1,2,3,4,5,6,7])
#       4 s1.plot()
# ----> 5 s1.show()
#
# C:\Anaconda3\envs\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'show'

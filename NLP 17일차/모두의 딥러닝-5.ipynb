# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.optim as optimizer
class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1)
    def forward(self, x):
        return self.linear(x)

model = MultivariateLinearRegressionModel()


class MyDataSET(Dataset):
    def __init__(self):
        self.x_data = ([
            [73,80,75],
            [93,88,93],
            [89,91,90],
            [96,98,100],
            [73,66,70], [73,80,75],
            [93,88,93],
            [89,91,90],
            [96,98,100],
            [73,66,70], [73,80,75],
            [93,88,93],
            [89,91,90],
            [96,98,100],
            [73,66,70]
        ])
        self.y_data = ([
            
            [152],[185],[180],[196],[142],
            [152],[185],[180],[196],[142],
            [152],[185],[180],[196],[142]
        ])
    def __len__(self):
        return len(self.x_data)
    
    def __getitem__(self,index):
        print(index , end=" ")
        x = torch.Tensor(self.x_data[index])
        y = torch.Tensor(self.y_data[index])
        return x,y

Dataset = MyDataSET()
optimizer_ =  optimizer.SGD(model.parameters(),lr= 1e-5)

# %%
dataloader_ = DataLoader(Dataset, batch_size = 3)
nb_epochs =20 
for epoch in range(nb_epochs+1):
    for batch_index,samples in enumerate(dataloader_):
        x_train, y_train = samples
        prediction = model(x_train)
        cost = F.mse_loss(prediction, y_train)
        optimizer_.zero_grad()
        cost.backward()
      
        optimizer_.step()
        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_index+1, len(dataloader_),
        cost.item()))
# Out:
# 0 1 2 Epoch    0/20 Batch 1/5 Cost: 4.029239
# 3 4 5 Epoch    0/20 Batch 2/5 Cost: 5.227946
# 6 7 8 Epoch    0/20 Batch 3/5 Cost: 2.929802
# 9 10 11 Epoch    0/20 Batch 4/5 Cost: 6.884386
# 12 13 14 Epoch    0/20 Batch 5/5 Cost: 4.617009
# 0 1 2 Epoch    1/20 Batch 1/5 Cost: 4.108175
# 3 4 5 Epoch    1/20 Batch 2/5 Cost: 5.234953
# 6 7 8 Epoch    1/20 Batch 3/5 Cost: 2.919594
# 9 10 11 Epoch    1/20 Batch 4/5 Cost: 6.825901
# 12 13 14 Epoch    1/20 Batch 5/5 Cost: 4.617915
# 0 1 2 Epoch    2/20 Batch 1/5 Cost: 4.102155
# 3 4 5 Epoch    2/20 Batch 2/5 Cost: 5.222228
# 6 7 8 Epoch    2/20 Batch 3/5 Cost: 2.913198
# 9 10 11 Epoch    2/20 Batch 4/5 Cost: 6.805734
# 12 13 14 Epoch    2/20 Batch 5/5 Cost: 4.608744
# 0 1 2 Epoch    3/20 Batch 1/5 Cost: 4.090834
# 3 4 5 Epoch    3/20 Batch 2/5 Cost: 5.208198
# 6 7 8 Epoch    3/20 Batch 3/5 Cost: 2.906980
# 9 10 11 Epoch    3/20 Batch 4/5 Cost: 6.787579
# 12 13 14 Epoch    3/20 Batch 5/5 Cost: 4.599060
# ...

# %% [markdown]
# # 글로벌 데이터 02 - World Bank, OECD, Eurostat
#
# <img src="http://i.imgur.com/grQHNKG.jpg">
#
# #### 2017 FinanceData http://fb.com/financedata

# %% [markdown]
# # World Bank
# * https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#world-bank

# %%
from pandas_datareader import wb
import datetime

wb.search('gdp.*capita.*const')[['id', 'name']]
# Out:
#                         id                                               name
# 646     6.0.GDPpc_constant  GDP per capita, PPP (constant 2011 internation...
# 8098        NY.GDP.PCAP.KD                 GDP per capita (constant 2010 US$)
# 8100        NY.GDP.PCAP.KN                      GDP per capita (constant LCU)
# 8102     NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2011 internation...
# 8103  NY.GDP.PCAP.PP.KD.87  GDP per capita, PPP (constant 1987 internation...

# %%
from pandas_datareader import wb
import datetime

# 국가 코드
print( wb.country_codes[:20] )
# Out:
# ['AD', 'AE', 'AF', 'AG', 'AI', 'AL', 'AM', 'AO', 'AQ', 'AR', 'AS', 'AT', 'AU', 'AW', 'AX', 'AZ', 'BA', 'BB', 'BD', 'BE']

# %%
wb.search().head()
# Out:
#                       id                                               name  \
# 646   6.0.GDPpc_constant  GDP per capita, PPP (constant 2011 internation...
# 5007   FB.DPT.INSU.PC.ZS   Deposit insurance coverage (% of GDP per capita)
# 7800      NE.GDI.FTOT.CR  GDP expenditure on gross fixed capital formati...
# 7882   NV.AGR.PCAP.KD.ZG   Real agricultural GDP per capita growth rate (%)
# 8096      NY.GDP.PCAP.CD                       GDP per capita (current US$)
#
#                                                  source  \
# 646                                      LAC Equity Lab
# 5007                              WDI Database Archives
# 7800  Indonesia Database for Policy and Economic Res...
# 7882                      Africa Development Indicators
# 8096                       World Development Indicators
#
#                                              sourceNote  \
# 646   GDP per capita based on purchasing power parit...
# 5007
# 7800
# ...

# %%
len(wb.search())
# Out:
# 19

# %% [markdown]
# # GDP
# MKTGDPCNA646NWDB 중국 실질 GDP
#
# https://research.stlouisfed.org/fred2/series/MKTGDPCNA646NWDB

# %%
import pandas_datareader as pdr

df = pdr.DataReader("MKTGDPCNA646NWDB", 'fred', '2000', '2017')
df
# Out:
#             MKTGDPCNA646NWDB
# DATE
# 2000-01-01      1.211347e+12
# 2001-01-01      1.339396e+12
# 2002-01-01      1.470550e+12
# 2003-01-01      1.660288e+12
# 2004-01-01      1.955347e+12
# 2005-01-01      2.285966e+12
# 2006-01-01      2.752132e+12
# 2007-01-01      3.552182e+12
# 2008-01-01      4.598206e+12
# 2009-01-01      5.109954e+12
# 2010-01-01      6.100620e+12
# 2011-01-01      7.572554e+12
# 2012-01-01      8.560547e+12
# 2013-01-01      9.607224e+12
# 2014-01-01      1.048237e+13
# 2015-01-01      1.106467e+13
# 2016-01-01      1.119099e+13
# 2017-01-01      1.223770e+13

# %%
# %matplotlib inline
df.plot()

# %% [markdown]
# # Eurostat

# %%
# http://ec.europa.eu/eurostat/
# Rail accidents by type of accident    

df = pdr.DataReader("tran_sf_railac", 'eurostat')
df
# Out:
# ACCIDENT    Collisions of trains, including collisions with obstacles within the clearance gauge  \
# UNIT                                                                                      Number
# GEO                                                                                      Austria
# FREQ                                                                                      Annual
# TIME_PERIOD
# 2010-01-01                                                 3.0
# 2011-01-01                                                 2.0
# 2012-01-01                                                 1.0
# 2013-01-01                                                 4.0
# 2014-01-01                                                 1.0
# 2015-01-01                                                 7.0
# 2016-01-01                                                 7.0
#
# ACCIDENT                                                         \
# UNIT
# ...

# %% [markdown]
# # 문서
# * http://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# %% [markdown]
# ----
# ### 2018 FinanceData http://fb.com/financedata

# %%
1+1
# Out:
# 2

# %%
2-1

333-33

2-4

15 * 6

10 / 2


10 //2

3.5-5.1


1999999999999999999999999999999999999999+1

3/2*4-5/2

(5*4 - 15) + ((5-2)*(9-7))

type(4.5)

2**5

3e8

4e10 + 2

0b10001

0x11

0x123331

hex(13332)


0.0000000000000001

0.000001

0.01

0.001

0.0001

0.000001

0.00001

True and False

True or False


student = ["hello","heeeeello"]
type(student)

not False


print(5 ==3)

3<=5

not False

print((3>0) or (-5 >0))

a = 123
print(a-123)

a = "스트링입니다."
print(a)
type(a)

a = 'enjoy!'
b = 'python!'
print(a+' '+b)
print( a * 3 )
string1="""
공부할 것이 많다.!
아주! '예를 들어서 '
아주! '커피는 맛있다'
아주!
아주!
"""
print(string1)

string2 = "nlp 자연어처리"
print(string2)

abc = 2222214
print(abc)

List = [2]
print(List)
for i in List:
    print(i)

student1 = [90,95,80,85]
student1[-4]

mixedList = [0,2,3.14,['python','solidity','java']]






Number_list =[1,2,3,4,5,6,7,8,9]
print(Number_list[4:8][1])
print(Number_list[0:10])
print(Number_list[0::3])
print(Number_list[0::2])
print(Number_list[0:7:2])
print( 5 in Number_list)
if(5 in Number_list):
    Number_list.remove(5)
    print(Number_list)
    Number_list.append([4,5])
    last = Number_list.pop()
    print(last)
    print(Number_list)

myFriends_list = ['james','robert','lisa','mary']
print (myFriends_list.count("sangwon"))
myFriends_list.sort()
print(myFriends_list)
myFriends_list.count('james')
myFriends_list.reverse()

tuple1=('a','a','b',1,2,1,1)
print(tuple1.count(1))
print(tuple1.index(1))
# Out:
# 1

# %%
set_A ={1,1,2,5,3,'a','c','b'}
set_B ={'a','b','c','d'}
print(set_A.intersection(set_B))
print(set_A&set_B)
print(set_A.difference(set_B))
print(set_A-set_B)
print(set_A.union(set_B))
print(set_A|set_B)



dictionary_ = {
    1 : "하나",
    2 : "둘",
    3 : "셋"
}

print(dictionary_.keys())
print(dictionary_.values())
print(dictionary_.items())
dictionary_[4]="넷"
print(dictionary_)
sub_dictionary = {5:"다섯", 6:"여섯"}
dictionary_.update(sub_dictionary)
print(dictionary_)

print(type(   dictionary_.values()   )   )
print(type(   list(dictionary_.values()   )    )   )

print(type(dictionary_.items()))
# Out:
# {'a', 'c', 'b'}
# {'a', 'c', 'b'}
# {1, 2, 3, 5}
# {1, 2, 3, 5}
# {1, 2, 3, 5, 'b', 'a', 'c', 'd'}
# {1, 2, 3, 5, 'b', 'a', 'c', 'd'}

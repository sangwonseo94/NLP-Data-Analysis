# %%
import pandas as pd
from tqdm import trange

# %%
Food = pd.read_excel("아침식단/남성50-64세01밥두류찌개어패류구이채소만볶2.xlsx")
Food.index = [i for i in range(len(Food))]
Food.drop_duplicates(['국','메인'],keep='first')
# Out:
#             밥           국    메인        서브       유사도
# 0          조밥        비지찌개  굴비구이      부추볶음  0.999287
# 1        완두콩밥        비지찌개  방어구이  감자볶음(당근)  0.998408
# 2          팥밥     비지찌개(콩)  굴비구이  김치볶음(참치)  0.998330
# 3          팥밥     비지찌개(콩)  방어구이     고구마볶음  0.998208
# 4          팥밥       순두부찌개  방어구이  감자볶음(어묵)  0.998067
# 5      콩밥(대두)       연두부찌개  방어구이      근대볶음  0.997959
# 16     콩밥(대두)       연두부찌개  새치구이  감자볶음(어묵)  0.996024
# 19        보리밥   두부찌개(고추장)  굴비구이     고구마볶음  0.995965
# 21     콩밥(대두)        감자찌개  방어구이  감자볶음(어묵)  0.995961
# 22        차조밥       연두부찌개  굴비구이  감자볶음(어묵)  0.995946
# 23        차조밥   두부찌개(고추장)  방어구이  감자볶음(어묵)  0.995884
# 29     콩밥(대두)  감자찌개(돼지고기)  장어구이  김치볶음(참치)  0.995212
# 32       보리콩밥  감자찌개(돼지고기)  굴비구이  김치볶음(참치)  0.995072
# 35   잡곡밥(옥수수)       연두부찌개  장어구이     고구마볶음  0.994950
# 39         팥밥        비지찌개  새치구이  감자볶음(어묵)  0.994819
# 57        보리밥        두부찌개  방어구이  감자볶음(어묵)  0.994216
# 98     콩밥(대두)        두부찌개  굴비구이     취나물볶음  0.992219
# ...

# %%
# Out:
#             밥           국    메인             서브       유사도
# 0          조밥        비지찌개  굴비구이           부추볶음  0.999287
# 1        완두콩밥        비지찌개  방어구이       감자볶음(당근)  0.998408
# 2          팥밥     비지찌개(콩)  굴비구이       김치볶음(참치)  0.998330
# 3          팥밥     비지찌개(콩)  방어구이          고구마볶음  0.998208
# 4          팥밥       순두부찌개  방어구이       감자볶음(어묵)  0.998067
# 5      콩밥(대두)       연두부찌개  방어구이           근대볶음  0.997959
# 6         현미밥        비지찌개  방어구이          고구마볶음  0.997804
# 7         현미밥        비지찌개  방어구이       김치볶음(참치)  0.997377
# 8        차수수밥        비지찌개  굴비구이           죽순볶음  0.996339
# 9          팥밥        비지찌개  굴비구이           미역볶음  0.996303
# 10       검정콩밥        비지찌개  방어구이           죽순볶음  0.996259
# 11   잡곡밥(옥수수)        비지찌개  방어구이          풋고추볶음  0.996192
# 12        땅콩밥        비지찌개  방어구이       감자볶음(어묵)  0.996158
# 13   잡곡밥(옥수수)        비지찌개  굴비구이          고사리볶음  0.996155
# 14   잡곡밥(옥수수)        비지찌개  방어구이  김치볶음(동물성재료없음)  0.996140
# ...
